# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 1: Loading Datasets

# %%
import os


print(os.getcwd())
# Out:
# c:\projects\ml-pipeline\notebooks

# %%
df1 = pd.read_csv(r"C:\projects\ml-pipeline\data\raw\nykaa_campaign_data_with_nulls.csv", encoding = 'utf-8')
df2 = pd.read_csv(r"C:\projects\ml-pipeline\data\raw\purplle_campaign_data_with_nulls.csv", encoding= 'utf-8')
df3 = pd.read_csv(r"C:\projects\ml-pipeline\data\raw\tira_campaign_data_with_nulls.csv", encoding= 'utf-8')

# %% [markdown]
# ### Step 2: Data Cleaning

# %% [markdown]
# #### 2A. Dataset1

# %%
df1.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  NY-CMP-1000  Social Media       College Students      21.0
# 1  NY-CMP-1001      Paid Ads  Tier 2 City Customers      18.0
# 2  NY-CMP-1002    Influencer                  Youth      23.0
# 3  NY-CMP-1003         Email          Working Women      18.0
# 4  NY-CMP-1004      Paid Ads       College Students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             WhatsApp, YouTube      57804.0  6156.0  3616.0       2355.0
# 1                       YouTube      91801.0  3321.0  1971.0       1357.0
# 2     WhatsApp, Google, YouTube      15536.0  2182.0   952.0        755.0
# 3  YouTube, Facebook, Instagram      88114.0  8413.0  2231.0        947.0
# 4           Facebook, Instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0               NaN  6.14    Hindi             20.98
# ...

# %%
df1['Brand_Name'] = 'Nykaa'
df1.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  NY-CMP-1000  Social Media       College Students      21.0
# 1  NY-CMP-1001      Paid Ads  Tier 2 City Customers      18.0
# 2  NY-CMP-1002    Influencer                  Youth      23.0
# 3  NY-CMP-1003         Email          Working Women      18.0
# 4  NY-CMP-1004      Paid Ads       College Students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             WhatsApp, YouTube      57804.0  6156.0  3616.0       2355.0
# 1                       YouTube      91801.0  3321.0  1971.0       1357.0
# 2     WhatsApp, Google, YouTube      15536.0  2182.0   952.0        755.0
# 3  YouTube, Facebook, Instagram      88114.0  8413.0  2231.0        947.0
# 4           Facebook, Instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0               NaN  6.14    Hindi             20.98
# ...

# %% [markdown]
# #### 2B.Dataset2

# %%
df2.head()
# Out:
#    Campaign_ID Campaign_Type   Target_Audience  Duration         Channel_Used  \
# 0  PU-CMP-1000      Paid Ads     Working Women       6.0     Facebook, Google
# 1  PU-CMP-1001      Paid Ads  Premium Shoppers       8.0  Instagram, WhatsApp
# 2  PU-CMP-1002    Influencer             Youth      22.0   Facebook, WhatsApp
# 3  PU-CMP-1003      Paid Ads             Youth      15.0  Instagram, WhatsApp
# 4  PU-CMP-1004  Social Media  Premium Shoppers      11.0  WhatsApp, Instagram
#
#    Impressions  Clicks   Leads  Conversions    Revenue  Acquisition_Cost  \
# 0      31869.0  3490.0  1946.0        902.0   493394.0             55.93
# 1      26640.0  2441.0   741.0        314.0   108644.0            197.44
# 2      36967.0  4997.0  1025.0        653.0        NaN            234.59
# 3      73258.0  5893.0  2565.0       1970.0  1341570.0            103.76
# 4      91081.0  6393.0  3282.0       2582.0   787510.0             78.61
#
# ...

# %%
df2['Brand_Name'] = 'Purplle'
df2.head()
# Out:
#    Campaign_ID Campaign_Type   Target_Audience  Duration         Channel_Used  \
# 0  PU-CMP-1000      Paid Ads     Working Women       6.0     Facebook, Google
# 1  PU-CMP-1001      Paid Ads  Premium Shoppers       8.0  Instagram, WhatsApp
# 2  PU-CMP-1002    Influencer             Youth      22.0   Facebook, WhatsApp
# 3  PU-CMP-1003      Paid Ads             Youth      15.0  Instagram, WhatsApp
# 4  PU-CMP-1004  Social Media  Premium Shoppers      11.0  WhatsApp, Instagram
#
#    Impressions  Clicks   Leads  Conversions    Revenue  Acquisition_Cost  \
# 0      31869.0  3490.0  1946.0        902.0   493394.0             55.93
# 1      26640.0  2441.0   741.0        314.0   108644.0            197.44
# 2      36967.0  4997.0  1025.0        653.0        NaN            234.59
# 3      73258.0  5893.0  2565.0       1970.0  1341570.0            103.76
# 4      91081.0  6393.0  3282.0       2582.0   787510.0             78.61
#
# ...

# %% [markdown]
# #### 2C. Dataset3

# %%
df3.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  TI-CMP-1000           SEO          Working Women      11.0
# 1  TI-CMP-1001  Social Media  Tier 2 City Customers      24.0
# 2  TI-CMP-1002           NaN          Working Women      28.0
# 3  TI-CMP-1003         Email                  Youth       8.0
# 4  TI-CMP-1004      Paid Ads       Premium Shoppers      15.0
#
#                 Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0                        NaN      64004.0  2906.0  1639.0        952.0
# 1                    YouTube      71795.0  2051.0   552.0        256.0
# 2                        NaN      79158.0  3546.0  1928.0       1314.0
# 3                     Google      31523.0  3721.0  2088.0        736.0
# 4  Facebook, Email, WhatsApp      61441.0  7277.0  3615.0       2602.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0   222768.0            129.72  0.80    Tamil               NaN
# ...

# %%
df3['Brand_Name'] = 'Tira'
df3.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  TI-CMP-1000           SEO          Working Women      11.0
# 1  TI-CMP-1001  Social Media  Tier 2 City Customers      24.0
# 2  TI-CMP-1002           NaN          Working Women      28.0
# 3  TI-CMP-1003         Email                  Youth       8.0
# 4  TI-CMP-1004      Paid Ads       Premium Shoppers      15.0
#
#                 Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0                        NaN      64004.0  2906.0  1639.0        952.0
# 1                    YouTube      71795.0  2051.0   552.0        256.0
# 2                        NaN      79158.0  3546.0  1928.0       1314.0
# 3                     Google      31523.0  3721.0  2088.0        736.0
# 4  Facebook, Email, WhatsApp      61441.0  7277.0  3615.0       2602.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0   222768.0            129.72  0.80    Tamil               NaN
# ...

# %% [markdown]
# ### Combining all datasets

# %%
df= pd.concat([df1,df2,df3], ignore_index=True)
df.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  NY-CMP-1000  Social Media       College Students      21.0
# 1  NY-CMP-1001      Paid Ads  Tier 2 City Customers      18.0
# 2  NY-CMP-1002    Influencer                  Youth      23.0
# 3  NY-CMP-1003         Email          Working Women      18.0
# 4  NY-CMP-1004      Paid Ads       College Students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             WhatsApp, YouTube      57804.0  6156.0  3616.0       2355.0
# 1                       YouTube      91801.0  3321.0  1971.0       1357.0
# 2     WhatsApp, Google, YouTube      15536.0  2182.0   952.0        755.0
# 3  YouTube, Facebook, Instagram      88114.0  8413.0  2231.0        947.0
# 4           Facebook, Instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0               NaN  6.14    Hindi             20.98
# ...

# %%
df.shape
# Out:
# (166665, 17)

# %%
df.tail()
# Out:
#          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 166660           NaN           NaN  Tier 2 City Customers      11.0
# 166661  TI-CMP-56551           SEO          Working Women      20.0
# 166662  TI-CMP-56552         Email                    NaN      13.0
# 166663           NaN    Influencer       Premium Shoppers      22.0
# 166664  TI-CMP-56554      Paid Ads          Working Women       NaN
#
#                      Channel_Used  Impressions   Clicks   Leads  Conversions  \
# 166660  Instagram, YouTube, Email          NaN   3799.0     NaN       1099.0
# 166661          Google, Instagram      54886.0   1578.0   634.0          NaN
# 166662        Facebook, Instagram      97954.0  11480.0  4567.0       2144.0
# 166663              Google, Email      11669.0      NaN   122.0         44.0
# 166664                  Instagram      50497.0   1604.0   542.0        363.0
#
#          Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# ...

# %%
df.sample(5)
# Out:
#          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 75108   PU-CMP-20553           NaN       Premium Shoppers       8.0
# 150362  TI-CMP-40252    Influencer       Premium Shoppers      28.0
# 65848   PU-CMP-11293      Paid Ads  Tier 2 City Customers      22.0
# 132663  TI-CMP-22553  Social Media  Tier 2 City Customers      21.0
# 45961   NY-CMP-46961           SEO                  Youth      10.0
#
#                      Channel_Used  Impressions   Clicks   Leads  Conversions  \
# 75108         Facebook, Instagram      72500.0   3275.0   918.0        568.0
# 150362                   WhatsApp      50013.0   3989.0  2287.0       1018.0
# 65848     Facebook, Email, Google      94345.0   6170.0  1302.0        909.0
# 132663  YouTube, Email, Instagram      85509.0   1757.0   760.0        352.0
# 45961     WhatsApp, Google, Email      70183.0  10002.0  2509.0       1513.0
#
#          Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0        NY-CMP-1000  Social Media       College Students      21.0
# 1        NY-CMP-1001      Paid Ads  Tier 2 City Customers      18.0
# 2        NY-CMP-1002    Influencer                  Youth      23.0
# 3        NY-CMP-1003         Email          Working Women      18.0
# 4        NY-CMP-1004      Paid Ads       College Students      10.0
# ...              ...           ...                    ...       ...
# 166660           NaN           NaN  Tier 2 City Customers      11.0
# 166661  TI-CMP-56551           SEO          Working Women      20.0
# 166662  TI-CMP-56552         Email                    NaN      13.0
# 166663           NaN    Influencer       Premium Shoppers      22.0
# 166664  TI-CMP-56554      Paid Ads          Working Women       NaN
#
#                         Channel_Used  Impressions   Clicks   Leads  \
# ...

# %%
df.describe()
# Out:
#             Duration    Impressions         Clicks          Leads  \
# count  158342.000000  158441.000000  158441.000000  158575.000000
# mean       17.488582   55068.759456    4684.973978    1872.167157
# std         7.501765   25961.688169    3177.355919    1430.272768
# min         5.000000   10001.000000     202.000000      48.000000
# 25%        11.000000   32599.000000    2110.000000     779.000000
# 50%        17.000000   55113.000000    3908.000000    1476.000000
# 75%        24.000000   77582.000000    6695.000000    2600.000000
# max        30.000000  100000.000000   14944.000000    8876.000000
#
#          Conversions       Revenue  Acquisition_Cost           ROI  \
# count  158665.000000  1.583610e+05     158504.000000  158367.00000
# mean     1028.498213  5.138267e+05        376.830560       2.69620
# std       857.687806  4.875933e+05        536.701697       4.48544
# min        17.000000  3.895000e+03          8.180000      -0.99000
# ...

# %%
df.isnull().sum()
# Out:
# Campaign_ID         5417
# Campaign_Type       8358
# Target_Audience     8172
# Duration            8323
# Channel_Used        8282
# Impressions         8224
# Clicks              8224
# Leads               8090
# Conversions         8000
# Revenue             8304
# Acquisition_Cost    8161
# ROI                 8298
# Language            8299
# Engagement_Score    8081
# Customer_Segment    8175
# Date                8099
# Brand_Name             0
# dtype: int64

# %%
missing_pct = (df.isnull().sum()/ len(df))* 100
missing_pct
# Out:
# Campaign_ID         3.250233
# Campaign_Type       5.014850
# Target_Audience     4.903249
# Duration            4.993850
# Channel_Used        4.969250
# Impressions         4.934449
# Clicks              4.934449
# Leads               4.854049
# Conversions         4.800048
# Revenue             4.982450
# Acquisition_Cost    4.896649
# ROI                 4.978850
# Language            4.979450
# Engagement_Score    4.848648
# Customer_Segment    4.905049
# Date                4.859449
# Brand_Name          0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['Campaign_ID', 'Campaign_Type', 'Target_Audience', 'Duration',
#        'Channel_Used', 'Impressions', 'Clicks', 'Leads', 'Conversions',
#        'Revenue', 'Acquisition_Cost', 'ROI', 'Language', 'Engagement_Score',
#        'Customer_Segment', 'Date', 'Brand_Name'],
#       dtype='str')

# %%
df.drop('Campaign_ID', inplace=True, axis = 1)

# %%
df.head(5)
# Out:
#   Campaign_Type        Target_Audience  Duration  \
# 0  Social Media       College Students      21.0
# 1      Paid Ads  Tier 2 City Customers      18.0
# 2    Influencer                  Youth      23.0
# 3         Email          Working Women      18.0
# 4      Paid Ads       College Students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             WhatsApp, YouTube      57804.0  6156.0  3616.0       2355.0
# 1                       YouTube      91801.0  3321.0  1971.0       1357.0
# 2     WhatsApp, Google, YouTube      15536.0  2182.0   952.0        755.0
# 3  YouTube, Facebook, Instagram      88114.0  8413.0  2231.0        947.0
# 4           Facebook, Instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0               NaN  6.14    Hindi             20.98
# 1  1046247.0            180.83  3.26    Hindi              7.24
# ...

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Campaign_Type
# Influencer      31817
# Email           31801
# Paid Ads        31604
# SEO             31570
# Social Media    31515
# Name: count, dtype: int64
# Target_Audience
# Premium Shoppers         31927
# Working Women            31782
# Youth                    31733
# Tier 2 City Customers    31573
# College Students         31478
# Name: count, dtype: int64
# Duration
# 10.0    6200
# 6.0     6200
# 17.0    6190
# 24.0    6188
# 25.0    6178
# 16.0    6155
# 7.0     6152
# 13.0    6149
# 9.0     6141
# 29.0    6138
# 30.0    6124
# 21.0    6119
# 8.0     6116
# 11.0    6086
# 19.0    6085
# 27.0    6060
# 22.0    6054
# 20.0    6053
# 15.0    6034
# 12.0    6022
# 18.0    6000
# 26.0    5995
# 23.0    5993
# 14.0    5982
# 28.0    5982
# 5.0     5946
# Name: count, dtype: int64
# Channel_Used
# Email                           8953
# Instagram                       8858
# Facebook                        8791
# Google                          8740
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\2394721818.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# ##### Columns split into Categorical, Numerical, Datetime

# %%
date_cols = df.select_dtypes(include=['datetime64[ns]'])
print(date_cols)
print('Total date cols:', len(date_cols))
# Out:
#              Date
# 0      2025-04-29
# 1      2025-04-06
# 2      2025-01-14
# 3      2025-06-04
# 4      2024-12-29
# ...           ...
# 166660 2024-11-12
# 166661 2024-08-25
# 166662 2025-04-15
# 166663 2024-07-21
# 166664 2025-05-02
#
# [166665 rows x 1 columns]
# Total date cols: 166665

# %%
cat_cols = df.select_dtypes(include=['object']).columns
print(cat_cols)
print('Total cat cols :', len(cat_cols))
# Out:
# Index(['Campaign_Type', 'Target_Audience', 'Channel_Used', 'Language',
#        'Customer_Segment', 'Brand_Name'],
#       dtype='str')
# Total cat cols : 6
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\3673311930.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object']).columns

# %%
num_cols= df.select_dtypes(exclude=['object', 'datetime64[ns]']).columns
print(num_cols)
print('Total num cols:', len(num_cols))
# Out:
# Index(['Duration', 'Impressions', 'Clicks', 'Leads', 'Conversions', 'Revenue',
#        'Acquisition_Cost', 'ROI', 'Engagement_Score'],
#       dtype='str')
# Total num cols: 9

# %%
pd.DataFrame(df[num_cols])
# Out:
#         Duration  Impressions   Clicks   Leads  Conversions    Revenue  \
# 0           21.0      57804.0   6156.0  3616.0       2355.0  1867515.0
# 1           18.0      91801.0   3321.0  1971.0       1357.0  1046247.0
# 2           23.0      15536.0   2182.0   952.0        755.0   197055.0
# 3           18.0      88114.0   8413.0  2231.0        947.0   376906.0
# 4           10.0      96871.0   3743.0  2060.0       1258.0   518296.0
# ...          ...          ...      ...     ...          ...        ...
# 166660      11.0          NaN   3799.0     NaN       1099.0   454986.0
# 166661      20.0      54886.0   1578.0   634.0          NaN   136514.0
# 166662      13.0      97954.0  11480.0  4567.0       2144.0   445952.0
# 166663      22.0      11669.0      NaN   122.0         44.0    26884.0
# 166664       NaN      50497.0   1604.0   542.0        363.0   281688.0
#
#         Acquisition_Cost   ROI  Engagement_Score
# 0                    NaN  6.14             20.98
# ...

# %%
pd.DataFrame(df[cat_cols])
# Out:
#        Campaign_Type        Target_Audience                  Channel_Used  \
# 0       Social Media       College Students             WhatsApp, YouTube
# 1           Paid Ads  Tier 2 City Customers                       YouTube
# 2         Influencer                  Youth     WhatsApp, Google, YouTube
# 3              Email          Working Women  YouTube, Facebook, Instagram
# 4           Paid Ads       College Students           Facebook, Instagram
# ...              ...                    ...                           ...
# 166660           NaN  Tier 2 City Customers     Instagram, YouTube, Email
# 166661           SEO          Working Women             Google, Instagram
# 166662         Email                    NaN           Facebook, Instagram
# 166663    Influencer       Premium Shoppers                 Google, Email
# 166664      Paid Ads          Working Women                     Instagram
#
#        Language       Customer_Segment Brand_Name
# ...

# %% [markdown]
# #### Handling missing values

# %%
for col in num_cols:
    df[col].hist(grid=False,  edgecolor="white")
    plt.title(col)
    plt.show()

# %% [markdown]
# ➡️ Most of my numerical columns is skewed so using median to fill missing values
#
# ➡️Using Histogram plot to see my numerical columns data and distribution

# %%
for col in num_cols:
    df[col]= df[col].fillna(df[col].median())

# %%
for col in num_cols:
    df[col].hist(grid=False,  edgecolor="white")
    plt.title(col)
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(15,5))
    sns.countplot(x= df[col], palette='colorblind')
    plt.title(col)
    plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\1762328914.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\1762328914.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\1762328914.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# ...

# %% [markdown]
# ➡️ Using Proportionate method on Categorical columns to fill missing values
#
# ➡️Using Countplot to see my Categorical columns data and distribution

# %%
for col in cat_cols:
   proportions= df[col].dropna().value_counts(normalize=True)
   missing_mask = df[col].isnull()
   df.loc[missing_mask, col] = np.random.choice(

    proportions.index, size = missing_mask.sum(), p= proportions.values)

# %%
df.isna().sum()
# Out:
# Campaign_Type          0
# Target_Audience        0
# Duration               0
# Channel_Used           0
# Impressions            0
# Clicks                 0
# Leads                  0
# Conversions            0
# Revenue                0
# Acquisition_Cost       0
# ROI                    0
# Language               0
# Engagement_Score       0
# Customer_Segment       0
# Date                8099
# Brand_Name             0
# dtype: int64

# %%
for col in cat_cols:
    plt.figure(figsize=(15,5))
    sns.countplot(x= df[col], palette='colorblind')
    plt.title(col)
    plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\412919129.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\412919129.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\412919129.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= df[col], palette='colorblind')
# C:\Users\dell\AppData\Local\Temp\ipykernel_29428\412919129.py:3: FutureWarning:
#
# ...

# %% [markdown]
# ➡️Using ffill method to fill missing values in Date column

# %%
df['Date'] = df['Date'].ffill()

# %%
df['Date'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Campaign_Type       0
# Target_Audience     0
# Duration            0
# Channel_Used        0
# Impressions         0
# Clicks              0
# Leads               0
# Conversions         0
# Revenue             0
# Acquisition_Cost    0
# ROI                 0
# Language            0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# Brand_Name          0
# dtype: int64

# %% [markdown]
# #### Duplicate values Inspection

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Outliers Inspection

# %%
df.describe()
# Out:
#             Duration    Impressions         Clicks          Leads  \
# count  166665.000000  166665.000000  166665.000000  166665.000000
# mean       17.464183   55070.942483    4646.634590    1852.937011
# min         5.000000   10001.000000     202.000000      48.000000
# 25%        11.000000   33783.000000    2185.000000     809.000000
# 50%        17.000000   55113.000000    3908.000000    1476.000000
# 75%        24.000000   76427.000000    6510.000000    2525.000000
# max        30.000000  100000.000000   14944.000000    8876.000000
# std         7.312826   25313.049988    3102.538446    1397.723107
#
#          Conversions       Revenue  Acquisition_Cost            ROI  \
# count  166665.000000  1.666650e+05     166665.000000  166665.000000
# mean     1016.330177  5.061062e+05        368.599021       2.623698
# min        17.000000  3.895000e+03          8.180000      -0.990000
# 25%       417.000000  1.854360e+05        111.100000       0.090000
# ...

# %%
num_cols
# Out:
# Index(['Duration', 'Impressions', 'Clicks', 'Leads', 'Conversions', 'Revenue',
#        'Acquisition_Cost', 'ROI', 'Engagement_Score'],
#       dtype='str')

# %% [markdown]
# ➡️ Most of columns has Outliers present and highly skewed which is related to the Revenue and Marketing Cost
#
# ➡️Using Boxplot to identify Outliers

# %%
for col in num_cols:
    plt.boxplot(df[col], medianprops={"color": "blue"})
    plt.title(col)
    plt.show()

# %% [markdown]
# #### Fixing Categorical Columns

# %%
cat_cols
# Out:
# Index(['Campaign_Type', 'Target_Audience', 'Channel_Used', 'Language',
#        'Customer_Segment', 'Brand_Name'],
#       dtype='str')

# %%
df['Brand_Name'].unique()
# Out:
# <ArrowStringArray>
# ['Nykaa', 'Purplle', 'Tira']
# Length: 3, dtype: str

# %%
for col in cat_cols:
    df[col] = df[col].str.lower()
    df[col] = df[col].str.strip()

# %%
pd.DataFrame(df[cat_cols])
# Out:
#        Campaign_Type        Target_Audience                  Channel_Used  \
# 0       social media       college students             whatsapp, youtube
# 1           paid ads  tier 2 city customers                       youtube
# 2         influencer                  youth     whatsapp, google, youtube
# 3              email          working women  youtube, facebook, instagram
# 4           paid ads       college students           facebook, instagram
# ...              ...                    ...                           ...
# 166660           seo  tier 2 city customers     instagram, youtube, email
# 166661           seo          working women             google, instagram
# 166662         email  tier 2 city customers           facebook, instagram
# 166663    influencer       premium shoppers                 google, email
# 166664      paid ads          working women                     instagram
#
#        Language       Customer_Segment Brand_Name
# ...

# %%
df['Brand_Name'].unique()
# Out:
# <ArrowStringArray>
# ['nykaa', 'purplle', 'tira']
# Length: 3, dtype: str

# %%
df['Channel_Used'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Campaign_Type       0
# Target_Audience     0
# Duration            0
# Channel_Used        0
# Impressions         0
# Clicks              0
# Leads               0
# Conversions         0
# Revenue             0
# Acquisition_Cost    0
# ROI                 0
# Language            0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# Brand_Name          0
# dtype: int64

# %%
df['Channel_Used'] = df['Channel_Used'].str.split(",")

# %%
df['Channel_Used'] = df['Channel_Used'].fillna('Unknown')
df["Channel_Used"] = df["Channel_Used"].apply(lambda x: sorted([i.strip() for i in x]))
df["Channel_Used"] = df["Channel_Used"].apply(lambda x: ", ".join(x))

# %%
multiple = df["Channel_Used"].apply(lambda x: len(x.split(",")) > 1).sum()
single   = df["Channel_Used"].apply(lambda x: len(x.split(",")) == 1).sum()

# %%
print(f"Single channel rows: {single}")
print(f"Multiple channel rows: {multiple}")
# Out:
# Single channel rows: 55400
# Multiple channel rows: 111265

# %%
df["Channel_Used"].value_counts()
# Out:
# Channel_Used
# email                            9412
# instagram                        9303
# google                           9214
# facebook                         9207
# youtube                          9137
# whatsapp                         9127
# email, facebook                  3818
# instagram, youtube               3814
# email, whatsapp                  3774
# google, whatsapp                 3762
# email, google                    3746
# facebook, youtube                3738
# facebook, google                 3729
# whatsapp, youtube                3724
# email, youtube                   3716
# instagram, whatsapp              3695
# email, instagram                 3686
# google, instagram                3662
# google, youtube                  3607
# facebook, instagram              3574
# facebook, whatsapp               3540
# google, instagram, youtube       2861
# email, facebook, whatsapp        2847
# facebook, instagram, youtube     2845
# ...

# %%
df.head()
# Out:
#   Campaign_Type        Target_Audience  Duration  \
# 0  social media       college students      21.0
# 1      paid ads  tier 2 city customers      18.0
# 2    influencer                  youth      23.0
# 3         email          working women      18.0
# 4      paid ads       college students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             whatsapp, youtube      57804.0  6156.0  3616.0       2355.0
# 1                       youtube      91801.0  3321.0  1971.0       1357.0
# 2     google, whatsapp, youtube      15536.0  2182.0   952.0        755.0
# 3  facebook, instagram, youtube      88114.0  8413.0  2231.0        947.0
# 4           facebook, instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0           208.725  6.14    hindi             20.98
# 1  1046247.0           180.830  3.26    hindi              7.24
# ...

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# ➡️Bivariate analysis is done  to study the relationship between two columns. Here I am  going to compare the relationship between target column and other feature columns. It helps to understand how well my feature and target is corelated or related.

# %%
print(num_cols)
len(num_cols)
# Out:
# Index(['Duration', 'Impressions', 'Clicks', 'Leads', 'Conversions', 'Revenue',
#        'Acquisition_Cost', 'ROI', 'Engagement_Score'],
#       dtype='str')
# 9

# %%
print(cat_cols)
len(cat_cols)
# Out:
# Index(['Campaign_Type', 'Target_Audience', 'Channel_Used', 'Language',
#        'Customer_Segment', 'Brand_Name'],
#       dtype='str')
# 6

# %%
target = df['Revenue'], df['ROI']

# %% [markdown]
# ➡️ Analysis between Numerical columns and target->df['Revenue']

# %%
features = [col for col in num_cols if col != target]

fig, ax = plt.subplots(len(features), 2, figsize=(12, 4*len(features)))
for i, col in enumerate(features):

    # Scatterplot
    sns.scatterplot(
        x=df[col],
        y=df['Revenue'],
        ax=ax[i,0]
    )

    ax[i,0].set_title(f"{col} vs {'Revenue'}")

    # Boxplot
    sns.boxplot(
        x=df[col],
        ax=ax[i,1]
    )

    ax[i,1].set_title(f"{col} Boxplot")

plt.tight_layout()
plt.show()

# %% [markdown]
# ➡️ Analysis between Categorical columns and target -> df['ROI']

# %%
features = [col for col in cat_cols if col != target]
fig,ax = plt.subplots(len(features), 2, figsize = (12,4*len(features)))
for i , col in enumerate(features):

    #boxplot
    sns.boxplot(x=df[col], y=df['ROI'], ax=ax[i,0])
    ax[i,0].set_title(f"{col} vs ROI")

     #Barchart
    sns.barplot(x=df[col], y=df['ROI'], ax=ax[i,1])
    ax[i,1].set_title(f"{col} vs ROI ")
   
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ➡️Multivariate analysis is done to study relationships among multiple variables simultaneously and understand how they interact together to influence the target variable.

# %%
corr_matrix= df[num_cols].corr()
corr_matrix
# Out:
#                   Duration  Impressions    Clicks     Leads  Conversions  \
# Duration          1.000000    -0.003860 -0.000473 -0.001361    -0.000830
# Impressions      -0.003860     1.000000  0.660463  0.588167     0.539622
# Clicks           -0.000473     0.660463  1.000000  0.844100     0.773935
# Leads            -0.001361     0.588167  0.844100  1.000000     0.871138
# Conversions      -0.000830     0.539622  0.773935  0.871138     1.000000
# Revenue           0.000043     0.473056  0.678404  0.764217     0.831357
# Acquisition_Cost -0.000338    -0.412679 -0.455427 -0.447828    -0.437927
# ROI              -0.002183     0.367634  0.529325  0.598024     0.650388
# Engagement_Score  0.001579     0.002354  0.594170  0.632520     0.609598
#
#                    Revenue  Acquisition_Cost       ROI  Engagement_Score
# Duration          0.000043         -0.000338 -0.002183          0.001579
# Impressions       0.473056         -0.412679  0.367634          0.002354
# ...

# %%
sns.heatmap(corr_matrix, annot=True, fmt='.1f', linewidths=0.5)
plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# ### Analyze campaign performance across brands

# %%
df['Campaign_Type'].value_counts()
# Out:
# Campaign_Type
# influencer      33536
# email           33483
# paid ads        33307
# social media    33182
# seo             33157
# Name: count, dtype: int64

# %% [markdown]
# ➡️ We can see that, all Brands- Tira, Nykaa and Purpelle has generated relatively similar Revenue through all types of Campaign.
#
# ➡️ An SEO (Search Engine Optimization) campaign is a strategic, step-by-step plan to
# make your website rank higher on search engines like Google

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Campaign_Type'], y=df['Revenue'], hue=df['Brand_Name'], palette='colorblind')
plt.legend(title='Brand Name', loc='upper right', bbox_to_anchor=(1.15, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Identify top-performing and low-performing campaigns

# %%
campaign_performance = df.groupby(['Campaign_Type', 'Brand_Name']).agg({'Revenue': 'sum', 'ROI': 'mean', 'Leads':'sum', 'Conversions': 'sum'}).reset_index()
campaign_performance
# Out:
#    Campaign_Type Brand_Name       Revenue       ROI       Leads  Conversions
# 0          email      nykaa  5.629142e+09  2.601278  20546653.0   11315619.0
# 1          email    purplle  5.686491e+09  2.619240  20861871.0   11421809.0
# 2          email       tira  5.661753e+09  2.634670  20576502.0   11298897.0
# 3     influencer      nykaa  5.682425e+09  2.626570  20671088.0   11419310.0
# 4     influencer    purplle  5.636860e+09  2.577985  20789762.0   11345930.0
# 5     influencer       tira  5.586196e+09  2.603338  20476680.0   11209163.0
# 6       paid ads      nykaa  5.675754e+09  2.663558  20659530.0   11367487.0
# 7       paid ads    purplle  5.657934e+09  2.640596  20570279.0   11275953.0
# 8       paid ads       tira  5.660290e+09  2.652994  20700688.0   11354958.0
# 9            seo      nykaa  5.553196e+09  2.648895  20435083.0   11136027.0
# 10           seo    purplle  5.497640e+09  2.606094  20287931.0   11078844.0
# ...

# %%
campaign_performance.sort_values(ascending=False, by='Revenue')
# Out:
#    Campaign_Type Brand_Name       Revenue       ROI       Leads  Conversions
# 1          email    purplle  5.686491e+09  2.619240  20861871.0   11421809.0
# 3     influencer      nykaa  5.682425e+09  2.626570  20671088.0   11419310.0
# 6       paid ads      nykaa  5.675754e+09  2.663558  20659530.0   11367487.0
# 12  social media      nykaa  5.666637e+09  2.678588  20846766.0   11480938.0
# 2          email       tira  5.661753e+09  2.634670  20576502.0   11298897.0
# 8       paid ads       tira  5.660290e+09  2.652994  20700688.0   11354958.0
# 7       paid ads    purplle  5.657934e+09  2.640596  20570279.0   11275953.0
# 4     influencer    purplle  5.636860e+09  2.577985  20789762.0   11345930.0
# 0          email      nykaa  5.629142e+09  2.601278  20546653.0   11315619.0
# 13  social media    purplle  5.624920e+09  2.610803  20498541.0   11277338.0
# 5     influencer       tira  5.586196e+09  2.603338  20476680.0   11209163.0
# ...

# %% [markdown]
# ➡️ SEO, social media, and other campaign types showed comparable performance across all brands, suggesting a balanced marketing strategy.

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=campaign_performance['Campaign_Type'], y=campaign_performance['Revenue'], hue=campaign_performance['Brand_Name'], palette='colorblind')
plt.legend(title='Brand Name', loc='upper right', bbox_to_anchor=(1.15, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relationships between spend, clicks, revenue, and ROI

# %%
spend_cost= df.groupby('Brand_Name').agg({'Acquisition_Cost':'sum', 'Clicks':'sum', 'Leads': 'mean', 'Conversions': 'mean'}).reset_index()
spend_cost
# Out:
#   Brand_Name  Acquisition_Cost       Clicks        Leads  Conversions
# 0      nykaa      2.050185e+07  258411036.0  1856.882729  1020.959068
# 1    purplle      2.054240e+07  258060097.0  1854.169454  1015.207884
# 2       tira      2.038831e+07  257960221.0  1847.758852  1012.823580

# %% [markdown]
# ➡️ As per the graph, all Brands has eaually spent money on acquisition and promotional activities(acquisition cost)
#
# ➡️ All Brands has  generated similar number of customers through Clicks(Number of users who clicked on the campaign).
#
# ➡️ No of leads(potential customers) generated for all Brands is consistent. (Leads).
#
# ➡️ All the 3 Brands has performed similarly into turning all potential customers into buying through their Campaign(Conversions).

# %%
plt.figure(figsize=(10,5))
sns.heatmap(spend_cost.set_index('Brand_Name'), fmt= '.1f', annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Analyze channel-wise effectiveness

# %%
df.head()
# Out:
#   Campaign_Type        Target_Audience  Duration  \
# 0  social media       college students      21.0
# 1      paid ads  tier 2 city customers      18.0
# 2    influencer                  youth      23.0
# 3         email          working women      18.0
# 4      paid ads       college students      10.0
#
#                    Channel_Used  Impressions  Clicks   Leads  Conversions  \
# 0             whatsapp, youtube      57804.0  6156.0  3616.0       2355.0
# 1                       youtube      91801.0  3321.0  1971.0       1357.0
# 2     google, whatsapp, youtube      15536.0  2182.0   952.0        755.0
# 3  facebook, instagram, youtube      88114.0  8413.0  2231.0        947.0
# 4           facebook, instagram      96871.0  3743.0  2060.0       1258.0
#
#      Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515.0           208.725  6.14    hindi             20.98
# 1  1046247.0           180.830  3.26    hindi              7.24
# ...

# %%
df['Channel_Used'].unique()
# Out:
# <ArrowStringArray>
# [            'whatsapp, youtube',                       'youtube',
#      'google, whatsapp, youtube',  'facebook, instagram, youtube',
#            'facebook, instagram',              'email, instagram',
#                          'email',     'email, facebook, whatsapp',
#      'facebook, google, youtube',             'facebook, youtube',
#     'email, facebook, instagram',                     'instagram',
#                       'whatsapp',    'google, instagram, youtube',
#                'google, youtube',       'email, google, whatsapp',
#               'facebook, google',   'google, instagram, whatsapp',
#     'email, instagram, whatsapp',      'email, facebook, youtube',
#     'facebook, google, whatsapp', 'facebook, instagram, whatsapp',
#   'instagram, whatsapp, youtube',             'google, instagram',
#                         'google',            'facebook, whatsapp',
#                'email, facebook',     'email, instagram, youtube',
# ...

# %%
top_channels= df['Channel_Used'].value_counts().nlargest(10).index
top_channels
# Out:
# Index(['email', 'instagram', 'google', 'facebook', 'youtube', 'whatsapp',
#        'email, facebook', 'instagram, youtube', 'email, whatsapp',
#        'google, whatsapp'],
#       dtype='str', name='Channel_Used')

# %%
filtered_df = df[df['Channel_Used'].isin(top_channels)]
filtered_df
# Out:
#        Campaign_Type        Target_Audience  Duration        Channel_Used  \
# 1           paid ads  tier 2 city customers      18.0             youtube
# 7       social media          working women       6.0               email
# 9           paid ads       college students      11.0               email
# 13               seo                  youth      14.0               email
# 14          paid ads       premium shoppers       5.0           instagram
# ...              ...                    ...       ...                 ...
# 166648           seo  tier 2 city customers      21.0  instagram, youtube
# 166654           seo  tier 2 city customers      23.0              google
# 166656  social media       premium shoppers      14.0           instagram
# 166659      paid ads       premium shoppers      26.0            facebook
# 166664      paid ads          working women      17.0           instagram
#
#         Impressions  Clicks   Leads  Conversions    Revenue  Acquisition_Cost  \
# ...

# %% [markdown]
# ➡️ Channels like Instagram and Youtube has helped Brands like Tira and Purpelle and while for Nykaa,
#
#  Channels like Facebook and Whatsapp has helped in their business, though there is not a major difference among all the Channels , all has
#
#  performed relatively similar for all the Brands.

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=filtered_df['Channel_Used'], y=filtered_df['Revenue'], hue=filtered_df['Brand_Name'], palette='colorblind')
plt.legend(title='Brand Name', loc='lower right', bbox_to_anchor=(1.15, 1))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
